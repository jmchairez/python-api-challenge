# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from citipy import citipy
import random
import json
from config import api_key

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

lat_range = (-90, 90)
lng_range = (-180, 180)

output_file = "output_data/cities.csv"

# %%
#List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %%
weather_data = pd.DataFrame({"City": [],
                             "Country": [],
                             "Latitude": [],
                             "Longitude": [],
                             "Max Temp": [],
                             "Humidity": [],
                             "Cloud Cover": [],
                             "Wind Speed": [],
                             "Date": []})

print("Beginning Data Retrieval")
print("--------------------------------")
count = 1    
for i in range(100):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 1 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Retrieving record 1 of Set 1 | taolanaro
# City data not found, Skipping...
# Retrieving record 1 of Set 1 | aguia branca
# Retrieving record 2 of Set 1 | nelson bay
# Retrieving record 3 of Set 1 | puerto ayora
# Retrieving record 4 of Set 1 | georgetown
# Retrieving record 5 of Set 1 | vaitupu
# City data not found, Skipping...
# Retrieving record 5 of Set 1 | matata
# Retrieving record 6 of Set 1 | jamestown
# Retrieving record 7 of Set 1 | abu zabad
# Retrieving record 8 of Set 1 | busselton
# Retrieving record 9 of Set 1 | rikitea
# Retrieving record 10 of Set 1 | lolua
# City data not found, Skipping...
# Retrieving record 10 of Set 1 | sydney mines
# Retrieving record 11 of Set 1 | butaritari
# Retrieving record 12 of Set 1 | mahebourg
# Retrieving record 13 of Set 1 | kiruna
# Retrieving record 14 of Set 1 | victoria
# Retrieving record 15 of Set 1 | castro
# Retrieving record 16 of Set 1 | yar-sale
# ...

# %%
for i in range(100, 200):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 2 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Retrieving record 93 of Set 2 | mirabad
# Retrieving record 94 of Set 2 | cuamba
# Retrieving record 95 of Set 2 | saint-philippe
# Retrieving record 96 of Set 2 | airai
# Retrieving record 97 of Set 2 | taoudenni
# Retrieving record 98 of Set 2 | east london
# Retrieving record 99 of Set 2 | paita
# Retrieving record 100 of Set 2 | mys shmidta
# City data not found, Skipping...
# Retrieving record 100 of Set 2 | port keats
# Retrieving record 101 of Set 2 | sinnamary
# Retrieving record 102 of Set 2 | krasnyy chikoy
# Retrieving record 103 of Set 2 | bengkulu
# Retrieving record 104 of Set 2 | cape town
# Retrieving record 105 of Set 2 | kalcheva
# Retrieving record 106 of Set 2 | haines junction
# Retrieving record 107 of Set 2 | albany
# Retrieving record 108 of Set 2 | broome
# Retrieving record 109 of Set 2 | northam
# Retrieving record 110 of Set 2 | bluff
# Retrieving record 111 of Set 2 | umzimvubu
# City data not found, Skipping...
# Retrieving record 111 of Set 2 | sitka
# ...

# %%
for i in range(200, 300):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 3 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Retrieving record 184 of Set 3 | kavieng
# Retrieving record 185 of Set 3 | muhos
# Retrieving record 186 of Set 3 | micheweni
# Retrieving record 187 of Set 3 | tumannyy
# City data not found, Skipping...
# Retrieving record 187 of Set 3 | khatanga
# Retrieving record 188 of Set 3 | qui nhon
# Retrieving record 189 of Set 3 | iqaluit
# Retrieving record 190 of Set 3 | solovetskiy
# City data not found, Skipping...
# Retrieving record 190 of Set 3 | port pirie
# Retrieving record 191 of Set 3 | mayahi
# Retrieving record 192 of Set 3 | wielun
# Retrieving record 193 of Set 3 | gurupi
# Retrieving record 194 of Set 3 | louisbourg
# City data not found, Skipping...
# Retrieving record 194 of Set 3 | ballina
# Retrieving record 195 of Set 3 | avarua
# Retrieving record 196 of Set 3 | jos
# Retrieving record 197 of Set 3 | laguna
# Retrieving record 198 of Set 3 | bolungarvik
# City data not found, Skipping...
# Retrieving record 198 of Set 3 | leningradskiy
# ...

# %%
for i in range(300, 400):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 4 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Retrieving record 272 of Set 4 | tigil
# Retrieving record 273 of Set 4 | gunjur
# Retrieving record 274 of Set 4 | kars
# Retrieving record 275 of Set 4 | goundam
# Retrieving record 276 of Set 4 | bahia blanca
# Retrieving record 277 of Set 4 | bage
# Retrieving record 278 of Set 4 | anshun
# Retrieving record 279 of Set 4 | fecamp
# Retrieving record 280 of Set 4 | poum
# Retrieving record 281 of Set 4 | rock springs
# Retrieving record 282 of Set 4 | kloulklubed
# Retrieving record 283 of Set 4 | bayir
# Retrieving record 284 of Set 4 | okha
# Retrieving record 285 of Set 4 | narsaq
# Retrieving record 286 of Set 4 | durusu
# Retrieving record 287 of Set 4 | baruun-urt
# Retrieving record 288 of Set 4 | caluquembe
# Retrieving record 289 of Set 4 | ipswich
# Retrieving record 290 of Set 4 | opuwo
# Retrieving record 291 of Set 4 | barth
# Retrieving record 292 of Set 4 | rawannawi
# City data not found, Skipping...
# Retrieving record 292 of Set 4 | dakar
# ...

# %%
for i in range(400, 500):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 5 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Retrieving record 366 of Set 5 | padang
# Retrieving record 367 of Set 5 | nhulunbuy
# Retrieving record 368 of Set 5 | lata
# Retrieving record 369 of Set 5 | calvinia
# Retrieving record 370 of Set 5 | alcudia
# Retrieving record 371 of Set 5 | abiy adi
# City data not found, Skipping...
# Retrieving record 371 of Set 5 | candolim
# Retrieving record 372 of Set 5 | mokhotlong
# Retrieving record 373 of Set 5 | wewak
# Retrieving record 374 of Set 5 | baisha
# Retrieving record 375 of Set 5 | bolshaya sosnova
# Retrieving record 376 of Set 5 | ingham
# Retrieving record 377 of Set 5 | kununurra
# Retrieving record 378 of Set 5 | dawlatabad
# Retrieving record 379 of Set 5 | takaka
# Retrieving record 380 of Set 5 | tirumullaivasal
# Retrieving record 381 of Set 5 | tommot
# Retrieving record 382 of Set 5 | berlevag
# Retrieving record 383 of Set 5 | marystown
# Retrieving record 384 of Set 5 | kudahuvadhoo
# Retrieving record 385 of Set 5 | severo-kurilsk
# ...

# %%
for i in range(500, 600):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 6 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
        
print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# Retrieving record 461 of Set 6 | van
# Retrieving record 462 of Set 6 | jidong
# Retrieving record 463 of Set 6 | tutoia
# Retrieving record 464 of Set 6 | ust-ishim
# Retrieving record 465 of Set 6 | mildura
# Retrieving record 466 of Set 6 | barreirinhas
# Retrieving record 467 of Set 6 | maceio
# Retrieving record 468 of Set 6 | fuling
# Retrieving record 469 of Set 6 | jaffna
# Retrieving record 470 of Set 6 | hamina
# Retrieving record 471 of Set 6 | kassala
# Retrieving record 472 of Set 6 | wuwei
# Retrieving record 473 of Set 6 | paralimni
# Retrieving record 474 of Set 6 | oriximina
# Retrieving record 475 of Set 6 | ixtapa
# Retrieving record 476 of Set 6 | katangli
# Retrieving record 477 of Set 6 | sobolevo
# Retrieving record 478 of Set 6 | san-pedro
# Retrieving record 479 of Set 6 | lulea
# Retrieving record 480 of Set 6 | praia da vitoria
# Retrieving record 481 of Set 6 | shenjiamen
# Retrieving record 482 of Set 6 | san patricio
# ...

# %%
weather_data.to_csv("weather_data.csv", index=False)
weather_data.head()
# Out:
#            City Country  Latitude  Longitude  Max Temp  Humidity  Cloud Cover  \
# 0  aguia branca      BR    -18.98     -40.74     64.47      84.0         22.0
# 1    nelson bay      AU    -32.72     152.15     70.00      82.0         75.0
# 2  puerto ayora      EC     -0.74     -90.35     65.66      87.0         77.0
# 3    georgetown      MY      5.41     100.34     78.80      94.0         40.0
# 4        matata      NZ    -37.88     176.75     59.00      58.0        100.0
#
#    Wind Speed          Date
# 0        1.72  1.600403e+09
# 1       12.75  1.600403e+09
# 2        9.24  1.600403e+09
# 3        3.36  1.600403e+09
# 4       11.99  1.600403e+09

# %%
import os
import csv

cities_csv = os.path.join("output_file")
cities_pd = pd.read_csv(cities_csv)
cities_pd.head()
# Out:
#    Unnamed: 0             City Country  Latitude  Longitude  Max Temp  \
# 0           0       whitehorse      CA     60.72    -135.05     55.40
# 1           1           atuona      PF     -9.80    -139.03     78.01
# 2           2      east london      ZA    -33.02      27.91     55.40
# 3           3            kutum      SD     14.20      24.67     75.36
# 4           4  bambous virieux      MU    -20.34      57.76     73.99
#
#    Humidity  Cloud Cover  Wind Speed          Date
# 0      30.0         75.0       17.22  1.600402e+09
# 1      76.0         20.0       19.60  1.600402e+09
# 2      82.0         23.0        9.17  1.600402e+09
# 3      42.0         36.0        2.75  1.600402e+09
# 4      64.0         20.0       11.41  1.600402e+09

# %%
cities_df = cities_pd[["Latitude", "Longitude", "Max Temp", "Humidity", "Cloud Cover", "Wind Speed", "Date"]]
cities_df.head()
# Out:
#    Latitude  Longitude  Max Temp  Humidity  Cloud Cover  Wind Speed  \
# 0     60.72    -135.05     55.40      30.0         75.0       17.22
# 1     -9.80    -139.03     78.01      76.0         20.0       19.60
# 2    -33.02      27.91     55.40      82.0         23.0        9.17
# 3     14.20      24.67     75.36      42.0         36.0        2.75
# 4    -20.34      57.76     73.99      64.0         20.0       11.41
#
#            Date
# 0  1.600402e+09
# 1  1.600402e+09
# 2  1.600402e+09
# 3  1.600402e+09
# 4  1.600402e+09

# %%
cities_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloud Cover  \
# count  541.000000  541.000000  541.000000  541.000000   541.000000
# mean    20.935989   15.995693   64.245675   71.526802    48.134935
# std     33.836330   91.926505   15.222354   19.881913    39.308211
# min    -54.800000 -179.170000   19.650000    7.000000     0.000000
# 25%     -8.100000  -68.510000   52.050000   60.000000     1.000000
# 50%     27.370000   20.920000   64.780000   77.000000    41.000000
# 75%     50.100000  102.040000   76.960000   87.000000    90.000000
# max     78.220000  179.320000  102.200000  100.000000   100.000000
#
#        Wind Speed          Date
# count  541.000000  5.410000e+02
# mean     8.307006  1.600402e+09
# std      5.669988  8.099924e+01
# min      0.540000  1.600402e+09
# 25%      4.230000  1.600402e+09
# 50%      7.000000  1.600402e+09
# 75%     11.410000  1.600402e+09
# max     39.500000  1.600402e+09

# %%
plt.figure(figsize=(10,6))
plt.scatter(cities_df["Latitude"], cities_df["Max Temp"])
plt.title("Latitude vs. Temperature Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %%
#The scatter plot Latitude vs. Temperature displays that cities close to the equater are warmer than cities away from it. 
#As the latitude comes closer to 0 the temparature rises.

# %%
plt.figure(figsize=(10,6))
plt.scatter(cities_df["Latitude"], cities_df["Humidity"])
plt.title("Latitude vs. Humidity Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Out:
# Text(0, 0.5, 'Humidity (%)')

# %%
#The scatter plot Latitude vs. Humidity shows to be high in the cities at or very close to the equater. As the latitude moves away from the equater, some cities
#show to have low humidity. Over all there are many cities that have high humidity regarless of how close they are to the equater.

# %%
plt.figure(figsize=(10,6))
plt.scatter(cities_df["Latitude"], cities_df["Cloud Cover"])
plt.title("Latitude vs. Cloud Cover Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")
# Out:
# Text(0, 0.5, 'Cloud Cover (%)')

# %%
#There is no pattern to how display a realtion in the Latitude vs. Cloud Cover plot. The plots are distriputed throughtout the entire graph with no story to tell.

# %%
plt.figure(figsize=(10,6))
plt.scatter(cities_df["Latitude"], cities_df["Wind Speed"])
plt.title("Latitude vs. Wind Speed Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %%
#Latitude vs. Wind Speed shows that over all wind speed is low close and far from the equater. The one exception is the few plots with the latitude close to -60.

# %%
#Linear Regression

# %%
northern_cities = cities_df[cities_df["Latitude"] > 0]
northern_cities.head()
# Out:
#    Latitude  Longitude  Max Temp  Humidity  Cloud Cover  Wind Speed  \
# 0     60.72    -135.05     55.40      30.0         75.0       17.22
# 3     14.20      24.67     75.36      42.0         36.0        2.75
# 5     30.58     -87.29     80.60      78.0          1.0        3.36
# 6     34.80    -106.54     70.00      30.0         40.0        8.05
# 7     20.89    -156.47     87.80      52.0          1.0       13.87
#
#            Date
# 0  1.600402e+09
# 3  1.600402e+09
# 5  1.600402e+09
# 6  1.600402e+09
# 7  1.600402e+09

# %%
southern_cities = cities_df[cities_df["Latitude"] < 0]
southern_cities.head()
# Out:
#     Latitude  Longitude  Max Temp  Humidity  Cloud Cover  Wind Speed  \
# 1      -9.80    -139.03     78.01      76.0         20.0       19.60
# 2     -33.02      27.91     55.40      82.0         23.0        9.17
# 4     -20.34      57.76     73.99      64.0         20.0       11.41
# 9     -54.80     -68.30     30.20      92.0         90.0       20.80
# 12    -46.19     168.86     52.00      76.0        100.0       23.00
#
#             Date
# 1   1.600402e+09
# 2   1.600402e+09
# 4   1.600402e+09
# 9   1.600402e+09
# 12  1.600402e+09

# %%
from scipy.stats import linregress
x_values = northern_cities["Latitude"]
y_values = northern_cities["Max Temp"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,6))
plt.scatter(northern_cities["Latitude"], northern_cities["Max Temp"])
plt.title("Northern Hemisphere: Latitude vs. Temperature Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.plot(x_values, regression_values, "red")
plt.annotate(line_eq, (5,95), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.6248553452793248

# %%
#Latitude vs Max Tempuration shows a clear corrolation. As you move away from the equater the temperature drops, with few exceptions.

# %%
from scipy.stats import linregress
x_svalues = southern_cities["Latitude"]
y_svalues = southern_cities["Max Temp"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_svalues, y_svalues)
regression_svalues = x_svalues * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,6))
plt.scatter(southern_cities["Latitude"], southern_cities["Max Temp"])
plt.title("Southern Hemisphere: Latitude vs. Temperature Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.plot(x_svalues, regression_svalues, "red")
plt.annotate(line_eq, (-55,95), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.49973518814516227

# %%
#For the southern hemisphere we also see a downward trend, but it is not as clear as the northern hemisphere.

# %%
from scipy.stats import linregress
x_values = northern_cities["Latitude"]
y_values = northern_cities["Humidity"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,6))
plt.scatter(northern_cities["Latitude"], northern_cities["Humidity"])
plt.title("Northern Hemisphere: Latitude vs. Humidity Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.plot(x_values, regression_values, "red")
plt.annotate(line_eq, (5,95), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0004637200985724106

# %%
#Humidity seems to stay high in the northern hemisphere. It seems to have a low point half way between the cities closes to the equater and the cities furthest away.

# %%
from scipy.stats import linregress
x_svalues = southern_cities["Latitude"]
y_svalues = southern_cities["Humidity"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_svalues, y_svalues)
regression_svalues = x_svalues * slope + intercept
line_seq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,6))
plt.scatter(southern_cities["Latitude"], southern_cities["Humidity"])
plt.title("Southern Hemisphere: Latitude vs. Humidity Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.plot(x_svalues, regression_svalues, "red")
plt.annotate(line_seq, (-55,95), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.004328272989030045

# %%
#Humidity for the southern hemisphere seems to stay scattered evenly between 50% to 100% for the cities -40 latitude for the equater.

# %%
from scipy.stats import linregress
x_values = northern_cities["Latitude"]
y_values = northern_cities["Cloud Cover"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,6))
plt.scatter(northern_cities["Latitude"], northern_cities["Cloud Cover"])
plt.title("Northern Hemisphere: Latitude vs. Cloud Cover Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

plt.plot(x_values, regression_values, "red")
plt.annotate(line_eq, (5,95), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0030973546286903655

# %%
#There is still no tend with cloud cover in just the cities north of the equater.

# %%
from scipy.stats import linregress
x_svalues = southern_cities["Latitude"]
y_svalues = southern_cities["Cloud Cover"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_svalues, y_svalues)
regression_svalues = x_svalues * slope + intercept
line_seq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,6))
plt.scatter(southern_cities["Latitude"], southern_cities["Cloud Cover"])
plt.title("Southern Hemisphere: Latitude vs. Cloud Cover Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")

plt.plot(x_svalues, regression_svalues, "red")
plt.annotate(line_seq, (-55,95), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0006176452373584438

# %%
#Cloud cover in the southern hemisphere appears to be lower than the north. It seems that there might be few cloudy days in the south.

# %%
from scipy.stats import linregress
x_values = northern_cities["Latitude"]
y_values = northern_cities["Wind Speed"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,6))
plt.scatter(northern_cities["Latitude"], northern_cities["Wind Speed"])
plt.title("Northern Hemisphere: Latitude vs. Wind Speed Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.plot(x_values, regression_values, "red")
plt.annotate(line_eq, (7.5,30), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.03809328012301309

# %%
#Wind speed is low in the north with the exception of the one plot about 70 latitude that show a high wind speed.

# %%
from scipy.stats import linregress
x_svalues = southern_cities["Latitude"]
y_svalues = southern_cities["Wind Speed"]

slope, intercept, rvalue, pvalue, stderr = linregress(x_svalues, y_svalues)
regression_svalues = x_svalues * slope + intercept
line_seq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,6))
plt.scatter(southern_cities["Latitude"], southern_cities["Wind Speed"])
plt.title("Southern Hemisphere: Latitude vs. Wind Speed Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.plot(x_svalues, regression_svalues, "red")
plt.annotate(line_seq, (-55,95), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.10408700766961208

# %%
#Wind speed appears to be higher in the southern hemisphere. The furtherest removed from the equater the stronger the wind speed.
