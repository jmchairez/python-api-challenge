# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from citipy import citipy
import random
import json
from config import api_key

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

lat_range = (-90, 90)
lng_range = (-180, 180)

output_file = "output_data/cities.csv"

# %%
#List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
weather_data = pd.DataFrame({"City": [],
                             "Country": [],
                             "Latitude": [],
                             "Longitude": [],
                             "Max Temp": [],
                             "Humidity": [],
                             "Cloud Cover": [],
                             "Wind Speed": [],
                             "Date": []})

print("Beginning Data Retrieval")
print("--------------------------------")
count = 1    
for i in range(100):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 1 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Retrieving record 1 of Set 1 | samarai
# Retrieving record 2 of Set 1 | port alfred
# Retrieving record 3 of Set 1 | marau
# Retrieving record 4 of Set 1 | voh
# Retrieving record 5 of Set 1 | manono
# Retrieving record 6 of Set 1 | jamestown
# Retrieving record 7 of Set 1 | ushuaia
# Retrieving record 8 of Set 1 | iqaluit
# Retrieving record 9 of Set 1 | bengkulu
# Retrieving record 10 of Set 1 | vezirkopru
# Retrieving record 11 of Set 1 | san cristobal
# Retrieving record 12 of Set 1 | poopo
# Retrieving record 13 of Set 1 | ponta do sol
# Retrieving record 14 of Set 1 | arraial do cabo
# Retrieving record 15 of Set 1 | hermanus
# Retrieving record 16 of Set 1 | praia da vitoria
# Retrieving record 17 of Set 1 | hasaki
# Retrieving record 18 of Set 1 | kavieng
# Retrieving record 19 of Set 1 | tiksi
# Retrieving record 20 of Set 1 | butaritari
# Retrieving record 21 of Set 1 | coquimbo
# Retrieving record 22 of Set 1 | naze
# Retrieving record 23 of Set 1 | orangeburg
# Retrieving record 24 of Set 1 | ilulissat
# Retrieving record 25 of Set 1 | thompson
# Retrieving record 26 of Set 1 | kapaa
# Retrieving record 27 of Set 1 | barentsburg
# City data not found, Skipping...
# Retrieving record 27 of Set 1 | namatanai
# Retrieving record 28 of Set 1 | bluff
# Retrieving record 29 of Set 1 | khatanga
# Retrieving record 30 of Set 1 | buala
# Retrieving record 31 of Set 1 | comodoro rivadavia
# Retrieving record 32 of Set 1 | hamilton
# Retrieving record 33 of Set 1 | albany
# Retrieving record 34 of Set 1 | mocambique
# City data not found, Skipping...
# Retrieving record 34 of Set 1 | punta arenas
# Retrieving record 35 of Set 1 | vaini
# Retrieving record 90 of Set 1 | laramie

# %%
for i in range(100, 200):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 2 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Retrieving record 91 of Set 2 | saskylakh
# Retrieving record 92 of Set 2 | zaysan
# Retrieving record 93 of Set 2 | klaksvik
# Retrieving record 94 of Set 2 | presidencia roque saenz pena
# Retrieving record 95 of Set 2 | san vicente
# Retrieving record 96 of Set 2 | eureka
# Retrieving record 97 of Set 2 | wladyslawowo
# Retrieving record 98 of Set 2 | williams lake
# Retrieving record 99 of Set 2 | phan rang
# City data not found, Skipping...
# Retrieving record 99 of Set 2 | kruisfontein
# Retrieving record 100 of Set 2 | nome
# Retrieving record 101 of Set 2 | mgandu
# Retrieving record 102 of Set 2 | saint-pierre
# Retrieving record 103 of Set 2 | provideniya
# Retrieving record 104 of Set 2 | vardo
# Retrieving record 105 of Set 2 | saint george
# Retrieving record 106 of Set 2 | storforshei
# Retrieving record 107 of Set 2 | chongwe
# Retrieving record 108 of Set 2 | imbituba
# Retrieving record 109 of Set 2 | aku
# Retrieving record 110 of Set 2 | wuchi
# Retrieving record 111 of Set 2 | cidreira
# Retrieving record 112 of Set 2 | lebu
# Retrieving record 113 of Set 2 | butterworth
# Retrieving record 114 of Set 2 | wamba
# Retrieving record 115 of Set 2 | deputatskiy
# Retrieving record 116 of Set 2 | yellowknife
# Retrieving record 117 of Set 2 | pangoa
# Retrieving record 118 of Set 2 | emerald
# Retrieving record 119 of Set 2 | vaitupu
# City data not found, Skipping...
# Retrieving record 119 of Set 2 | nantucket
# Retrieving record 120 of Set 2 | kenai
# Retrieving record 121 of Set 2 | kiunga
# Retrieving record 122 of Set 2 | methoni
# Retrieving record 123 of Set 2 | kilindoni
# Retrieving record 124 of Set 2 | chuy
# Retrieving record 125 of Set 2 | tabas
# Retrieving record 126 of Set 2 | shimoda
# Retrieving record 127 of Set 2 | umea
# Retrieving record 128 of Set 2 | leningradskiy
# Retrieving record 129 of Set 2 | margate
# Retrieving record 130 of Set 2 | champerico
# Retrieving record 131 of Set 2 | point pedro
# Retrieving record 132 of Set 2 | cape town
# Retrieving record 133 of Set 2 | sonoita
# Retrieving record 134 of Set 2 | faanui
# Retrieving record 135 of Set 2 | tungor
# Retrieving record 136 of Set 2 | oussouye
# Retrieving record 137 of Set 2 | sobolevo
# Retrieving record 138 of Set 2 | antofagasta
# Retrieving record 139 of Set 2 | matamoros
# Retrieving record 140 of Set 2 | bethel
# Retrieving record 141 of Set 2 | bolshaya chernigovka
# City data not found, Skipping...
# Retrieving record 141 of Set 2 | bredasdorp
# Retrieving record 142 of Set 2 | raudeberg
# Retrieving record 143 of Set 2 | sao filipe
# Retrieving record 144 of Set 2 | terme
# Retrieving record 145 of Set 2 | cockburn town
# Retrieving record 146 of Set 2 | victoria
# Retrieving record 147 of Set 2 | kaoma
# Retrieving record 148 of Set 2 | lolua
# City data not found, Skipping...
# Retrieving record 148 of Set 2 | aykhal
# Retrieving record 149 of Set 2 | ostrovnoy
# Retrieving record 150 of Set 2 | tumannyy
# City data not found, Skipping...
# Retrieving record 150 of Set 2 | labuhan
# Retrieving record 151 of Set 2 | newcastle
# Retrieving record 152 of Set 2 | popondetta
# Retrieving record 153 of Set 2 | bubaque
# Retrieving record 154 of Set 2 | altay
# Retrieving record 155 of Set 2 | mahebourg
# Retrieving record 156 of Set 2 | faya
# Retrieving record 157 of Set 2 | coahuayana
# Retrieving record 158 of Set 2 | cairns
# Retrieving record 159 of Set 2 | santa maria
# Retrieving record 160 of Set 2 | mareeba
# Retrieving record 161 of Set 2 | mangrol
# Retrieving record 162 of Set 2 | pastavy
# Retrieving record 163 of Set 2 | iisalmi
# Retrieving record 164 of Set 2 | vila
# Retrieving record 165 of Set 2 | oranjemund
# Retrieving record 166 of Set 2 | ribeira grande
# Retrieving record 167 of Set 2 | san pedro
# Retrieving record 168 of Set 2 | merritt island
# Retrieving record 169 of Set 2 | dalvik
# Retrieving record 170 of Set 2 | castro
# Retrieving record 171 of Set 2 | osypenko
# Retrieving record 172 of Set 2 | piacabucu
# Retrieving record 173 of Set 2 | carutapera
# Retrieving record 174 of Set 2 | berezovyy
# Retrieving record 175 of Set 2 | geraldton
# Retrieving record 176 of Set 2 | boa vista
# Retrieving record 177 of Set 2 | pisco
# Retrieving record 178 of Set 2 | tezu
# Retrieving record 179 of Set 2 | port hardy
# Retrieving record 180 of Set 2 | sur
# Retrieving record 181 of Set 2 | fostoria
# Retrieving record 182 of Set 2 | dingle
# Retrieving record 183 of Set 2 | illoqqortoormiut
# City data not found, Skipping...
# Retrieving record 183 of Set 2 | saint-louis
# Retrieving record 184 of Set 2 | washington

# %%
for i in range(200, 300):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 3 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
# Retrieving record 242 of Set 3 | topolobampo
# Retrieving record 243 of Set 3 | lazaro cardenas
# Retrieving record 244 of Set 3 | edea
# Retrieving record 245 of Set 3 | nakhon phanom
# Retrieving record 246 of Set 3 | majholi
# Retrieving record 247 of Set 3 | georgetown
# Retrieving record 248 of Set 3 | xichang
# Retrieving record 249 of Set 3 | san miguel
# Retrieving record 250 of Set 3 | saint-joseph
# Retrieving record 251 of Set 3 | yanam
# Retrieving record 252 of Set 3 | karratha
# Retrieving record 253 of Set 3 | horsham
# Retrieving record 254 of Set 3 | san quintin
# Retrieving record 255 of Set 3 | san patricio
# Retrieving record 256 of Set 3 | san joaquin
# Retrieving record 257 of Set 3 | hopkinsville
# Retrieving record 258 of Set 3 | tomatlan
# Retrieving record 259 of Set 3 | hami
# Retrieving record 260 of Set 3 | evensk
# Retrieving record 261 of Set 3 | port blair
# Retrieving record 262 of Set 3 | lardos
# Retrieving record 263 of Set 3 | bolungarvik
# City data not found, Skipping...
# Retrieving record 263 of Set 3 | richards bay
# Retrieving record 264 of Set 3 | concordia
# Retrieving record 265 of Set 3 | bam
# Retrieving record 266 of Set 3 | guilin
# Retrieving record 267 of Set 3 | yanan
# City data not found, Skipping...
# Retrieving record 267 of Set 3 | concepcion del oro
# Retrieving record 268 of Set 3 | perrenjas
# City data not found, Skipping...
# Retrieving record 268 of Set 3 | sola
# Retrieving record 269 of Set 3 | makakilo city
# Retrieving record 270 of Set 3 | karaul
# City data not found, Skipping...
# Retrieving record 270 of Set 3 | davila
# Retrieving record 271 of Set 3 | ferme-neuve
# Retrieving record 272 of Set 3 | leshukonskoye
# Retrieving record 273 of Set 3 | khani
# Retrieving record 274 of Set 3 | santa isabel do rio negro
# Retrieving record 275 of Set 3 | ketchikan
# Retrieving record 276 of Set 3 | melville
# Retrieving record 277 of Set 3 | kyra

# %%
for i in range(300, 400):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 4 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Retrieving record 278 of Set 4 | baisha
# Retrieving record 279 of Set 4 | castleisland
# Retrieving record 280 of Set 4 | mayo
# Retrieving record 281 of Set 4 | san antonio
# Retrieving record 282 of Set 4 | vestmanna
# Retrieving record 283 of Set 4 | palabuhanratu
# City data not found, Skipping...
# Retrieving record 345 of Set 4 | madang
# Retrieving record 346 of Set 4 | benguela
# Retrieving record 347 of Set 4 | tasgaon
# Retrieving record 348 of Set 4 | qafsah
# City data not found, Skipping...
# Retrieving record 348 of Set 4 | shakiso
# Retrieving record 349 of Set 4 | kachiry
# Retrieving record 350 of Set 4 | anito
# Retrieving record 351 of Set 4 | port-cartier
# Retrieving record 352 of Set 4 | shenjiamen
# Retrieving record 353 of Set 4 | hayden
# Retrieving record 354 of Set 4 | paka
# Retrieving record 355 of Set 4 | marcona
# City data not found, Skipping...
# Retrieving record 355 of Set 4 | husavik
# Retrieving record 356 of Set 4 | kaeo
# Retrieving record 357 of Set 4 | vila velha
# Retrieving record 358 of Set 4 | havre
# Retrieving record 359 of Set 4 | lata
# Retrieving record 360 of Set 4 | nortelandia
# Retrieving record 361 of Set 4 | jaunjelgava
# Retrieving record 362 of Set 4 | la paz
# Retrieving record 363 of Set 4 | coihueco
# Retrieving record 364 of Set 4 | nikki
# Retrieving record 365 of Set 4 | malatya
# Retrieving record 366 of Set 4 | west bay
# Retrieving record 367 of Set 4 | fort nelson
# Retrieving record 368 of Set 4 | severo-yeniseyskiy
# Retrieving record 369 of Set 4 | sept-iles
# Retrieving record 370 of Set 4 | comonfort
# Retrieving record 371 of Set 4 | banjar

# %%
for i in range(400, 500):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 5 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
# Out:
# Retrieving record 372 of Set 5 | narsaq
# Retrieving record 373 of Set 5 | acarau
# Retrieving record 374 of Set 5 | general bravo
# Retrieving record 375 of Set 5 | mao
# Retrieving record 376 of Set 5 | khanpur
# Retrieving record 377 of Set 5 | christchurch
# Retrieving record 378 of Set 5 | najran
# Retrieving record 379 of Set 5 | mizpe ramon
# City data not found, Skipping...
# Retrieving record 379 of Set 5 | kirakira
# Retrieving record 380 of Set 5 | esna
# Retrieving record 381 of Set 5 | maneadero
# Retrieving record 382 of Set 5 | beloha
# Retrieving record 383 of Set 5 | santa isabel
# Retrieving record 384 of Set 5 | krasnoye
# Retrieving record 385 of Set 5 | kidal
# Retrieving record 386 of Set 5 | olafsvik
# Retrieving record 387 of Set 5 | yuzhno-kurilsk
# Retrieving record 388 of Set 5 | vilhena
# Retrieving record 389 of Set 5 | dumai
# Retrieving record 390 of Set 5 | edinburg
# Retrieving record 391 of Set 5 | verkhoyansk
# Retrieving record 392 of Set 5 | lukovetskiy
# Retrieving record 393 of Set 5 | batagay
# Retrieving record 394 of Set 5 | ossora
# Retrieving record 395 of Set 5 | kangaba
# Retrieving record 396 of Set 5 | lasa
# Retrieving record 397 of Set 5 | assiniboia
# Retrieving record 398 of Set 5 | acapulco
# Retrieving record 399 of Set 5 | tucuma
# Retrieving record 400 of Set 5 | kamina
# Retrieving record 401 of Set 5 | nevinnomyssk
# Retrieving record 402 of Set 5 | linxia
# Retrieving record 403 of Set 5 | icod de los vinos
# Retrieving record 404 of Set 5 | corinto
# Retrieving record 405 of Set 5 | maniwaki
# Retrieving record 406 of Set 5 | sena madureira
# Retrieving record 407 of Set 5 | cerrito
# Retrieving record 408 of Set 5 | lotung
# City data not found, Skipping...
# Retrieving record 408 of Set 5 | along
# Retrieving record 409 of Set 5 | glenwood springs
# Retrieving record 410 of Set 5 | souillac
# Retrieving record 411 of Set 5 | dwarka
# Retrieving record 412 of Set 5 | las animas
# Retrieving record 413 of Set 5 | hay river
# Retrieving record 414 of Set 5 | colares
# Retrieving record 415 of Set 5 | roald
# Retrieving record 416 of Set 5 | warqla
# City data not found, Skipping...
# Retrieving record 416 of Set 5 | mehamn
# Retrieving record 417 of Set 5 | esperance
# Retrieving record 418 of Set 5 | qom
# Retrieving record 419 of Set 5 | bud
# Retrieving record 420 of Set 5 | ayan
# Retrieving record 421 of Set 5 | zheleznodorozhnyy
# Retrieving record 422 of Set 5 | alice
# Retrieving record 423 of Set 5 | sistranda
# Retrieving record 424 of Set 5 | talnakh
# Retrieving record 425 of Set 5 | mudanya
# Retrieving record 426 of Set 5 | dubbo
# Retrieving record 427 of Set 5 | pangnirtung
# Retrieving record 428 of Set 5 | chissamba
# Retrieving record 429 of Set 5 | broken hill
# Retrieving record 430 of Set 5 | rorvik
# Retrieving record 431 of Set 5 | sillod
# Retrieving record 432 of Set 5 | cascais
# Retrieving record 433 of Set 5 | belaya gora
# Retrieving record 434 of Set 5 | aykino
# Retrieving record 435 of Set 5 | careiro da varzea
# Retrieving record 436 of Set 5 | ust-maya
# Retrieving record 437 of Set 5 | ngunguru
# Retrieving record 438 of Set 5 | norman wells
# Retrieving record 439 of Set 5 | dasoguz
# Retrieving record 440 of Set 5 | katsuura
# Retrieving record 441 of Set 5 | barinas
# Retrieving record 442 of Set 5 | port hedland
# Retrieving record 443 of Set 5 | rafsanjan
# Retrieving record 444 of Set 5 | wanning
# Retrieving record 445 of Set 5 | broome
# Retrieving record 446 of Set 5 | chitral
# Retrieving record 447 of Set 5 | vallenar
# Retrieving record 448 of Set 5 | toppenish
# Retrieving record 449 of Set 5 | sarangani
# Retrieving record 450 of Set 5 | ruatoria
# City data not found, Skipping...
# Retrieving record 450 of Set 5 | mezen
# Retrieving record 451 of Set 5 | aklavik
# Retrieving record 452 of Set 5 | arlit
# Retrieving record 453 of Set 5 | dunmore town
# Retrieving record 454 of Set 5 | viligili
# City data not found, Skipping...
# Retrieving record 454 of Set 5 | beyneu
# Retrieving record 455 of Set 5 | severo-kurilsk
# Retrieving record 456 of Set 5 | khabary
# Retrieving record 457 of Set 5 | sisimiut
# Retrieving record 458 of Set 5 | walvis bay
# Retrieving record 459 of Set 5 | fortuna
# Retrieving record 460 of Set 5 | puerto cabezas
# Retrieving record 461 of Set 5 | samut songkhram
# Retrieving record 462 of Set 5 | ngukurr
# City data not found, Skipping...
# Retrieving record 462 of Set 5 | ampanihy
# Retrieving record 463 of Set 5 | surgana
# Retrieving record 464 of Set 5 | kirpilskaya
# Retrieving record 465 of Set 5 | isabela

# %%
for i in range(500, 600):
    try:
        query_url = f"{url}appid={api_key}&q={cities[i]}&units={units}"
        print(f"Retrieving record {count} of Set 6 | {cities[i]}")
        weather = requests.get(query_url).json()
    
        lat = weather["coord"]["lat"]
        lng = weather["coord"]["lon"]
        temp = weather["main"]["temp_max"]
        humidity = weather["main"]["humidity"]
        cloudiness = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        country = weather["sys"]["country"]
        date = weather["dt"]
        
        weather_data = weather_data.append({"City": cities[i], 
                                            "Country": country,
                                            "Latitude": lat,
                                            "Longitude": lng,
                                            "Max Temp": temp,
                                            "Humidity": humidity,
                                            "Cloud Cover": cloudiness,
                                            "Wind Speed": wind,
                                            "Date": date}, ignore_index=True)
        count+=1
    except:
        print(f"City data not found, Skipping...")
        
print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# Retrieving record 466 of Set 6 | francistown
# Retrieving record 467 of Set 6 | laguna
# Retrieving record 468 of Set 6 | olinda
# Retrieving record 469 of Set 6 | kita
# Retrieving record 470 of Set 6 | cap malheureux
# Retrieving record 471 of Set 6 | sulangan
# Retrieving record 472 of Set 6 | shache
# Retrieving record 473 of Set 6 | hobyo
# Retrieving record 474 of Set 6 | saint anthony
# Retrieving record 475 of Set 6 | flinders
# Retrieving record 476 of Set 6 | coihaique
# Retrieving record 477 of Set 6 | birao
# Retrieving record 478 of Set 6 | patacamaya
# Retrieving record 479 of Set 6 | tyssedal
# Retrieving record 480 of Set 6 | ugleuralskiy
# Retrieving record 481 of Set 6 | nkhata bay
# Retrieving record 482 of Set 6 | shima
# Retrieving record 483 of Set 6 | sooke
# Retrieving record 484 of Set 6 | sioux lookout
# Retrieving record 485 of Set 6 | sibolga
# Retrieving record 486 of Set 6 | barrancabermeja
# Retrieving record 487 of Set 6 | kununurra
# Retrieving record 488 of Set 6 | toktogul
# Retrieving record 489 of Set 6 | eyl
# Retrieving record 490 of Set 6 | bandarbeyla
# Retrieving record 491 of Set 6 | fevralsk
# City data not found, Skipping...
# Retrieving record 491 of Set 6 | vilyuysk
# Retrieving record 492 of Set 6 | ruiru
# Retrieving record 493 of Set 6 | powell river
# Retrieving record 494 of Set 6 | yunjinghong
# City data not found, Skipping...
# Retrieving record 494 of Set 6 | oistins
# Retrieving record 495 of Set 6 | iberia
# Retrieving record 496 of Set 6 | merrill
# Retrieving record 497 of Set 6 | dalbandin
# Retrieving record 498 of Set 6 | siderno
# Retrieving record 499 of Set 6 | tessalit
# Retrieving record 500 of Set 6 | garmsar
# Retrieving record 501 of Set 6 | wukari
# Retrieving record 502 of Set 6 | washougal
# Retrieving record 503 of Set 6 | riyadh
# Retrieving record 504 of Set 6 | skibbereen
# Retrieving record 505 of Set 6 | jaltenango
# Retrieving record 506 of Set 6 | cap-chat
# Retrieving record 507 of Set 6 | oktyabrskiy
# Retrieving record 508 of Set 6 | cobija
# Retrieving record 509 of Set 6 | haileybury
# Retrieving record 510 of Set 6 | ketchenery
# City data not found, Skipping...
# Retrieving record 510 of Set 6 | tondano
# Retrieving record 511 of Set 6 | sabha
# Retrieving record 512 of Set 6 | krasnoselkup
# Retrieving record 513 of Set 6 | aden
# Retrieving record 514 of Set 6 | ratnagiri
# Retrieving record 515 of Set 6 | fare
# Retrieving record 516 of Set 6 | nemuro
# Retrieving record 517 of Set 6 | tidore
# City data not found, Skipping...
# Retrieving record 517 of Set 6 | meyungs
# City data not found, Skipping...
# Retrieving record 517 of Set 6 | kokopo
# Retrieving record 518 of Set 6 | zapolyarnyy
# Retrieving record 519 of Set 6 | akyab
# Retrieving record 520 of Set 6 | greymouth
# Retrieving record 521 of Set 6 | hervey bay
# Retrieving record 522 of Set 6 | ukiah
# Retrieving record 523 of Set 6 | burnie
# Retrieving record 524 of Set 6 | grindavik
# Retrieving record 525 of Set 6 | tabulbah
# City data not found, Skipping...
# Retrieving record 525 of Set 6 | ipixuna
# Retrieving record 526 of Set 6 | lima
# Retrieving record 527 of Set 6 | pogranichnyy
# Retrieving record 528 of Set 6 | petropavlovsk-kamchatskiy
# Retrieving record 529 of Set 6 | skjervoy
# Retrieving record 530 of Set 6 | rutul
# Retrieving record 531 of Set 6 | vao
# Retrieving record 532 of Set 6 | dutlwe
# Retrieving record 533 of Set 6 | macapa
# Retrieving record 534 of Set 6 | thinadhoo
# Retrieving record 535 of Set 6 | hambantota
# Retrieving record 536 of Set 6 | half moon bay
# Retrieving record 537 of Set 6 | launceston
# Retrieving record 538 of Set 6 | kpandae
# Retrieving record 539 of Set 6 | biggar
# Retrieving record 540 of Set 6 | hokitika
# Retrieving record 541 of Set 6 | prince rupert
# Retrieving record 542 of Set 6 | rongcheng
# Retrieving record 543 of Set 6 | rolim de moura
# City data not found, Skipping...
# Retrieving record 543 of Set 6 | shurugwi
# Retrieving record 544 of Set 6 | mendahara
# City data not found, Skipping...
# Retrieving record 544 of Set 6 | quang ngai
# Retrieving record 545 of Set 6 | rungata
# City data not found, Skipping...
# Retrieving record 545 of Set 6 | tatarsk
# Retrieving record 546 of Set 6 | mimongo
# Retrieving record 547 of Set 6 | berlevag
# Retrieving record 548 of Set 6 | bhandara
# Retrieving record 549 of Set 6 | gorom-gorom
# Retrieving record 550 of Set 6 | listvyanka
# Retrieving record 551 of Set 6 | tiznit
# Retrieving record 552 of Set 6 | tual
# Retrieving record 553 of Set 6 | plettenberg bay
# Retrieving record 554 of Set 6 | ciras
# City data not found, Skipping...
# Retrieving record 554 of Set 6 | iralaya
# Retrieving record 555 of Set 6 | humaita
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
weather_data.to_csv("output_file")
weather_data.head()
# Out:
#           City Country  Latitude  Longitude  Max Temp  Humidity  Cloud Cover  \
# 0      samarai      PG    -10.62     150.67     79.07      86.0        100.0
# 1  port alfred      ZA    -33.59      26.89     59.00      73.0         32.0
# 2        marau      BR    -28.45     -52.20     65.23      93.0         16.0
# 3          voh      NC    -20.97     164.70     73.00      68.0          0.0
# 4       manono      CD     -7.30      27.42     78.31      52.0         25.0
#
#    Wind Speed          Date
# 0       17.16  1.600378e+09
# 1        6.58  1.600378e+09
# 2        3.00  1.600378e+09
# 3        5.30  1.600378e+09
# 4        1.66  1.600378e+09

# %%
import os
import csv

cities_csv = os.path.join("output_file")
cities_pd = pd.read_csv(cities_csv)
cities_pd.head()
# Out:
#    Unnamed: 0         City Country  Latitude  Longitude  Max Temp  Humidity  \
# 0           0      samarai      PG    -10.62     150.67     79.07      86.0
# 1           1  port alfred      ZA    -33.59      26.89     59.00      73.0
# 2           2        marau      BR    -28.45     -52.20     65.23      93.0
# 3           3          voh      NC    -20.97     164.70     73.00      68.0
# 4           4       manono      CD     -7.30      27.42     78.31      52.0
#
#    Cloud Cover  Wind Speed          Date
# 0        100.0       17.16  1.600378e+09
# 1         32.0        6.58  1.600378e+09
# 2         16.0        3.00  1.600378e+09
# 3          0.0        5.30  1.600378e+09
# 4         25.0        1.66  1.600378e+09

# %%
cities_df = cities_pd[["Latitude", "Longitude", "Max Temp", "Humidity", "Cloud Cover", "Wind Speed", "Date"]]
cities_df.head()
# Out:
#    Latitude  Longitude  Max Temp  Humidity  Cloud Cover  Wind Speed  \
# 0    -10.62     150.67     79.07      86.0        100.0       17.16
# 1    -33.59      26.89     59.00      73.0         32.0        6.58
# 2    -28.45     -52.20     65.23      93.0         16.0        3.00
# 3    -20.97     164.70     73.00      68.0          0.0        5.30
# 4     -7.30      27.42     78.31      52.0         25.0        1.66
#
#            Date
# 0  1.600378e+09
# 1  1.600378e+09
# 2  1.600378e+09
# 3  1.600378e+09
# 4  1.600378e+09

# %%
cities_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloud Cover  \
# count  555.000000  555.000000  555.000000  555.000000   555.000000
# mean    18.713676   15.907586   66.221676   70.200000    51.039640
# std     33.829464   91.920572   15.884186   22.139482    38.325867
# min    -54.800000 -175.200000   20.340000    3.000000     0.000000
# 25%     -9.840000  -66.850000   52.385000   58.000000     7.000000
# 50%     20.570000   19.030000   69.800000   77.000000    55.000000
# 75%     47.585000   97.475000   77.855000   87.000000    90.000000
# max     77.480000  179.320000  102.990000  100.000000   100.000000
#
#        Wind Speed          Date
# count  555.000000  5.550000e+02
# mean     8.116216  1.600378e+09
# std      5.880835  7.991728e+01
# min      0.180000  1.600378e+09
# 25%      3.680000  1.600378e+09
# 50%      6.930000  1.600378e+09
# 75%     10.290000  1.600378e+09
# max     36.910000  1.600378e+09

# %%
plt.figure(figsize=(10,6))
plt.scatter(cities_df["Latitude"], cities_df["Max Temp"])
plt.title("Latitude vs. Temperature Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %%
#The scatter plot Latitude vs. Temperature displays that cities close to the equater are warmer than cities away from it. 
#As the latitude comes closer to 0 the temparature rises.

# %%
plt.figure(figsize=(10,6))
plt.scatter(cities_df["Latitude"], cities_df["Humidity"])
plt.title("Latitude vs. Humidity Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %%
#The scatter plot Latitude vs. Humidity shows to be high in the cities at or very close to the equater. As the latitude moves away from the equater, some cities
#show to have low humidity. Over all there are many cities that have high humidity regarless of how close they are to the equater.

# %%
plt.figure(figsize=(10,6))
plt.scatter(cities_df["Latitude"], cities_df["Cloud Cover"])
plt.title("Latitude vs. Cloud Cover Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")
# Out:
# Text(0, 0.5, 'Cloud Cover (%)')

# %%
#There is no pattern to how display a realtion in the Latitude vs. Cloud Cover plot. The plots are distriputed throughtout the entire graph with no story to tell.

# %%
plt.figure(figsize=(10,6))
plt.scatter(cities_df["Latitude"], cities_df["Wind Speed"])
plt.title("Latitude vs. Wind Speed Plot (9/16/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')

# %%
#Latitude vs. Wind Speed shows that over all wind speed is low close and far from the equater. The one exception is the few plots with the latitude close to -60.

# %%
northern_cities = cities_df[cities_df["Latitude"] > 0]
northern_cities.head()
# Out:
#     Latitude  Longitude  Max Temp  Humidity  Cloud Cover  Wind Speed  \
# 5      42.10     -79.24     64.99      72.0         75.0       10.29
# 7      63.75     -68.51     41.00      74.0         75.0        3.02
# 9      41.14      35.45     62.60      42.0          0.0        5.82
# 10      7.77     -72.22     89.60      49.0         40.0       12.75
# 12     32.67     -17.10     71.60      64.0         20.0        5.82
#
#             Date
# 5   1.600378e+09
# 7   1.600378e+09
# 9   1.600378e+09
# 10  1.600378e+09
# 12  1.600378e+09

# %%
southern_cities = cities_df[cities_df["Latitude"] < 0]
southern_cities.head()
# Out:
#    Latitude  Longitude  Max Temp  Humidity  Cloud Cover  Wind Speed  \
# 0    -10.62     150.67     79.07      86.0        100.0       17.16
# 1    -33.59      26.89     59.00      73.0         32.0        6.58
# 2    -28.45     -52.20     65.23      93.0         16.0        3.00
# 3    -20.97     164.70     73.00      68.0          0.0        5.30
# 4     -7.30      27.42     78.31      52.0         25.0        1.66
#
#            Date
# 0  1.600378e+09
# 1  1.600378e+09
# 2  1.600378e+09
# 3  1.600378e+09
# 4  1.600378e+09
